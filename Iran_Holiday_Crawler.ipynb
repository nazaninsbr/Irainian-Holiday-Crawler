# %% [markdown]
# # Website 1
#
# link = https://www.timeanddate.com/holidays/iran/

# %%
import requests
from bs4 import BeautifulSoup

# %%
STAR_YEAR = 2014
END_YEAR = 2019

# %%
main_url = "https://www.timeanddate.com/holidays/iran/"
years = [str(year) for year in range(STAR_YEAR, END_YEAR+1)]
years
# Out:
# ['2014', '2015', '2016', '2017', '2018', '2019']

# %%
# getting the page contents
all_pages = {}
for year in years:
    r = requests.get(main_url+year)
    if not r.status_code == 200:
        raise RuntimeError('Problem accessing page data.')
    all_pages[year] = r.text
all_pages.keys()
# Out:
# dict_keys(['2014', '2015', '2016', '2017', '2018', '2019'])

# %%
# selecting the holiday tables
all_holiday_tables = {}
for year in years:
    soup = BeautifulSoup(all_pages[year], 'html.parser')
    holiday_table = soup.find("table", {"id":"holidays-table"})
    if not holiday_table == None:
        all_holiday_tables[year] = holiday_table
all_holiday_tables.keys()
# Out:
# dict_keys(['2014', '2015', '2016', '2017', '2018', '2019'])

# %%
# getting actual holiday rows 
all_holiday_rows = {}
for year in years:
    all_holiday_rows[year] = []
    holiday_rows = all_holiday_tables[year].find_all('tr')
    for row in holiday_rows:
        if 'data-date' in str(row):
            all_holiday_rows[year].append(row)
    print('For year {} the number of holidays are  {}'.format(year, len(all_holiday_rows[year])))
# Out:
# For year 2014 the number of holidays are  31
# For year 2015 the number of holidays are  30
# For year 2016 the number of holidays are  31
# For year 2017 the number of holidays are  31
# For year 2018 the number of holidays are  30
# For year 2019 the number of holidays are  22

# %%
all_holidays_and_occasions = {}
for year in years:
    all_holidays_and_occasions[year] = []
    for i in range(len(all_holiday_rows[year])):
        holiday_date = all_holiday_rows[year][i].find('th').text
        occasion = all_holiday_rows[year][i].find('a').text
        all_holidays_and_occasions[year].append([holiday_date, occasion])
all_holidays_and_occasions
# Out:
# {'2014': [['2 jan', 'Martyrdom of Imam Reza'],
#   ['19 jan', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#   ['11 fév', 'Revolution Day'],
#   ['20 mar', 'March Equinox'],
#   ['20 mar', 'Oil Nationalization Day'],
#   ['21 mar', 'Norooz (Persian New Year)'],
#   ['22 mar', 'Norooz Holiday'],
#   ['23 mar', 'Norooz Holiday'],
#   ['24 mar', 'Norooz Holiday'],
#   ['1 avr', 'Islamic Republic Day'],
#   ['2 avr', 'Nature Day'],
#   ['3 avr', 'Martyrdom of Fatima'],
#   ['13 mai', 'Birthday of Imam Ali'],
#   ['27 mai', "Prophet's Ascension"],
#   ['4 juin', "Anniversary of Khomeini's Death"],
#   ['5 juin', 'Revolt of Khordad 15'],
#   ['13 juin', "Imam Mahdi's birthday"],
#   ['21 juin', 'June Solstice'],
#   ['19 juil', 'Martyrdom of Imam Ali'],
#   ['29 juil', 'Eid-e-Fetr (End of Ramadan)'],
#   ['30 juil', 'Eid-e-Fetr (Additional Holiday)'],
#   ['22 aoû', 'Martyrdom of Imam Sadeq'],
#   ['23 sep', 'September Equinox'],
#   ['5 oct', 'Eid-e-Ghorban (Feast of Sacrifice)'],
#   ['13 oct', 'Eid-e-Ghadir'],
#   ['3 nov', 'Tassoua'],
#   ['4 nov', 'Ashura'],
#   ['13 déc', 'Arbaeen'],
#   ['22 déc', 'December Solstice'],
#   ['21 déc', 'Demise of Prophet Muhammad and Martyrdom of Imam Hassan'],
#   ['23 déc', 'Martyrdom of Imam Reza']],
#  '2015': [['9 jan', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#   ['11 fév', 'Revolution Day'],
#   ['21 mar', 'March Equinox'],
#   ['20 mar', 'Oil Nationalization Day'],
#   ['21 mar', 'Norooz (Persian New Year)'],
#   ['22 mar', 'Norooz Holiday'],
#   ['23 mar', 'Norooz Holiday'],
#   ['24 mar', 'Norooz Holiday'],
#   ['24 mar', 'Martyrdom of Fatima'],
#   ['1 avr', 'Islamic Republic Day'],
#   ['2 avr', 'Nature Day'],
#   ['2 mai', 'Birthday of Imam Ali'],
#   ['16 mai', "Prophet's Ascension"],
#   ['3 juin', "Imam Mahdi's birthday"],
#   ['4 juin', "Anniversary of Khomeini's Death"],
#   ['5 juin', 'Revolt of Khordad 15'],
#   ['21 juin', 'June Solstice'],
#   ['8 juil', 'Martyrdom of Imam Ali'],
#   ['18 juil', 'Eid-e-Fetr (End of Ramadan)'],
#   ['11 aoû', 'Martyrdom of Imam Sadeq'],
#   ['23 sep', 'September Equinox'],
#   ['24 sep', 'Eid-e-Ghorban (Feast of Sacrifice)'],
#   ['2 oct', 'Eid-e-Ghadir'],
#   ['23 oct', 'Tassoua'],
#   ['24 oct', 'Ashura'],
#   ['2 déc', 'Arbaeen'],
#   ['10 déc', 'Demise of Prophet Muhammad and Martyrdom of Imam Hassan'],
#   ['12 déc', 'Martyrdom of Imam Reza'],
#   ['22 déc', 'December Solstice'],
#   ['29 déc', 'Birthday of Prophet Muhammad and Imam Sadeq']],
#  '2016': [['11 fév', 'Revolution Day'],
#   ['13 mar', 'Martyrdom of Fatima'],
#   ['19 mar', 'Oil Nationalization Day'],
#   ['20 mar', 'March Equinox'],
#   ['20 mar', 'Norooz (Persian New Year)'],
#   ['21 mar', 'Norooz Holiday'],
#   ['22 mar', 'Norooz Holiday'],
#   ['23 mar', 'Norooz Holiday'],
#   ['31 mar', 'Islamic Republic Day'],
#   ['1 avr', 'Nature Day'],
#   ['21 avr', 'Birthday of Imam Ali'],
#   ['5 mai', "Prophet's Ascension"],
#   ['22 mai', "Imam Mahdi's birthday"],
#   ['3 juin', "Anniversary of Khomeini's Death"],
#   ['4 juin', 'Revolt of Khordad 15'],
#   ['21 juin', 'June Solstice'],
#   ['27 juin', 'Martyrdom of Imam Ali'],
#   ['6 juil', 'Eid-e-Fetr (End of Ramadan)'],
#   ['7 juil', 'Eid-e-Fetr (Additional Holiday)'],
#   ['31 juil', 'Martyrdom of Imam Sadeq'],
#   ['13 sep', 'Eid-e-Ghorban (Feast of Sacrifice)'],
#   ['21 sep', 'Eid-e-Ghadir'],
#   ['22 sep', 'September Equinox'],
#   ['11 oct', 'Tassoua'],
#   ['12 oct', 'Ashura'],
#   ['21 nov', 'Arbaeen'],
#   ['28 nov', 'Demise of Prophet Muhammad and Martyrdom of Imam Hassan'],
#   ['30 nov', 'Martyrdom of Imam Reza'],
#   ['8 déc', 'Martyrdom of Imam Hasan al-Askari'],
#   ['17 déc', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#   ['21 déc', 'December Solstice']],
#  '2017': [['11 fév', 'Revolution Day'],
#   ['2 mar', 'Martyrdom of Fatima'],
#   ['19 mar', 'Oil Nationalization Day'],
#   ['20 mar', 'March Equinox'],
#   ['21 mar', 'Norooz (Persian New Year)'],
#   ['22 mar', 'Norooz Holiday'],
#   ['23 mar', 'Norooz Holiday'],
#   ['24 mar', 'Norooz Holiday'],
#   ['1 avr', 'Islamic Republic Day'],
#   ['2 avr', 'Nature Day'],
#   ['11 avr', 'Birthday of Imam Ali'],
#   ['25 avr', "Prophet's Ascension"],
#   ['12 mai', "Imam Mahdi's birthday"],
#   ['4 juin', "Anniversary of Khomeini's Death"],
#   ['5 juin', 'Revolt of Khordad 15'],
#   ['16 juin', 'Martyrdom of Imam Ali'],
#   ['21 juin', 'June Solstice'],
#   ['26 juin', 'Eid-e-Fetr (End of Ramadan)'],
#   ['27 juin', 'Eid-e-Fetr (Additional Holiday)'],
#   ['20 juil', 'Martyrdom of Imam Sadeq'],
#   ['1 sep', 'Eid-e-Ghorban (Feast of Sacrifice)'],
#   ['9 sep', 'Eid-e-Ghadir'],
#   ['22 sep', 'September Equinox'],
#   ['30 sep', 'Tassoua'],
#   ['1 oct', 'Ashura'],
#   ['9 nov', 'Arbaeen'],
#   ['17 nov', 'Demise of Prophet Muhammad and Martyrdom of Imam Hassan'],
#   ['19 nov', 'Martyrdom of Imam Reza'],
#   ['27 nov', 'Martyrdom of Imam Hasan al-Askari'],
#   ['6 déc', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#   ['21 déc', 'December Solstice']],
#  '2018': [['11 fév', 'Revolution Day'],
#   ['20 mar', 'March Equinox'],
#   ['20 mar', 'Oil Nationalization Day'],
#   ['21 mar', 'Norooz (Persian New Year)'],
#   ['22 mar', 'Norooz Holiday'],
#   ['23 mar', 'Norooz Holiday'],
#   ['24 mar', 'Norooz Holiday'],
#   ['30 mar', 'Birthday of Imam Ali'],
#   ['1 avr', 'Islamic Republic Day'],
#   ['2 avr', 'Nature Day'],
#   ['13 avr', "Prophet's Ascension"],
#   ['2 mai', "Imam Mahdi's birthday"],
#   ['4 juin', "Anniversary of Khomeini's Death"],
#   ['5 juin', 'Revolt of Khordad 15'],
#   ['6 juin', 'Martyrdom of Imam Ali'],
#   ['15 juin', 'Eid-e-Fetr (End of Ramadan)'],
#   ['16 juin', 'Eid-e-Fetr (Additional Holiday)'],
#   ['21 juin', 'June Solstice'],
#   ['9 juil', 'Martyrdom of Imam Sadeq'],
#   ['21 aoû', 'Eid-e-Ghorban (Feast of Sacrifice)'],
#   ['29 aoû', 'Eid-e-Ghadir'],
#   ['19 sep', 'Tassoua'],
#   ['20 sep', 'Ashura'],
#   ['23 sep', 'September Equinox'],
#   ['30 oct', 'Arbaeen'],
#   ['7 nov', 'Demise of Prophet Muhammad and Martyrdom of Imam Hassan'],
#   ['8 nov', 'Martyrdom of Imam Reza'],
#   ['16 nov', 'Martyrdom of Imam Hasan al-Askari'],
#   ['25 nov', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#   ['22 déc', 'December Solstice']],
#  '2019': [['9 fév', 'Martyrdom of Fatima'],
#   ['11 fév', 'Revolution Day'],
#   ['21 mar', 'March Equinox'],
#   ['20 mar', 'Birthday of Imam Ali'],
#   ['3 avr', "Prophet's Ascension"],
#   ['21 avr', "Imam Mahdi's birthday"],
#   ['26 mai', 'Martyrdom of Imam Ali'],
#   ['5 juin', 'Eid-e-Fetr (End of Ramadan)'],
#   ['6 juin', 'Eid-e-Fetr (Additional Holiday)'],
#   ['21 juin', 'June Solstice'],
#   ['29 juin', 'Martyrdom of Imam Sadeq'],
#   ['12 aoû', 'Eid-e-Ghorban (Feast of Sacrifice)'],
#   ['20 aoû', 'Eid-e-Ghadir'],
#   ['9 sep', 'Tassoua'],
#   ['10 sep', 'Ashura'],
#   ['23 sep', 'September Equinox'],
#   ['20 oct', 'Arbaeen'],
#   ['28 oct', 'Demise of Prophet Muhammad and Martyrdom of Imam Hassan'],
#   ['29 oct', 'Martyrdom of Imam Reza'],
#   ['6 nov', 'Martyrdom of Imam Hasan al-Askari'],
#   ['15 nov', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#   ['22 déc', 'December Solstice']]}

# %%
finalized_holidays =[]
finalized_holidays.append('Date,Occasion\n')
month_mappings = {'jan': '01', 'fév': '02', 'mar': '03', 'avr': '04', 'mai': '05', 'juin': '06', 'juil': '07', 'aoû': '08', 'sep': '09', 'oct':'10', 'nov': '11', 'déc': '12'}
for year in years:
    for row in all_holidays_and_occasions[year]:
        date = row[0].split()
        h_date = str(year)+'-'+month_mappings[date[1]]+'-'+date[0]
        finalized_row = h_date+','+row[1]+'\n'
        finalized_holidays.append(finalized_row)
finalized_holidays[:5]
# Out:
# ['Date,Occasion\n',
#  '2014-01-2,Martyrdom of Imam Reza\n',
#  '2014-01-19,Birthday of Prophet Muhammad and Imam Sadeq\n',
#  '2014-02-11,Revolution Day\n',
#  '2014-03-20,March Equinox\n']

# %%
with open('holidays_'+str(STAR_YEAR)+'_'+str(END_YEAR)+'_v1.csv', 'w+') as fp:
    for row in finalized_holidays:
        fp.write(row)

# %%
import pandas as pd
file_content = pd.read_csv('holidays_'+str(STAR_YEAR)+'_'+str(END_YEAR)+'_v1.csv')
file_content.head()
# Out:
#          Date                                     Occasion
# 0   2014-01-2                       Martyrdom of Imam Reza
# 1  2014-01-19  Birthday of Prophet Muhammad and Imam Sadeq
# 2  2014-02-11                               Revolution Day
# 3  2014-03-20                                March Equinox
# 4  2014-03-20                      Oil Nationalization Day

# %% [markdown]
# # Website 2
#
# link = https://calendarific.com/holidays/2019/IR

# %%
url_start = "https://calendarific.com/holidays/"
url_end = "/IR"

# %%
all_pages_2 = {}
for year in years:
    r = requests.get(url_start+year+url_end)
    if not r.status_code == 200:
        raise RuntimeError('Problem accessing page data.')
    all_pages_2[year] = r.text
all_pages_2.keys()
# Out:
# dict_keys(['2014', '2015', '2016', '2017', '2018', '2019'])

# %%
all_holiday_tables_2 = {}
for year in years:
    soup = BeautifulSoup(all_pages_2[year], 'html.parser')
    holiday_table = soup.find("table")
    if 'holiday-list' in str(holiday_table):
        all_holiday_tables_2[year] = holiday_table
all_holiday_tables_2.keys()
# Out:
# dict_keys(['2014', '2015', '2016', '2017', '2018', '2019'])

# %%
all_holiday_rows_2 = {}
for year in years:
    all_holiday_rows_2[year] = []
    holiday_rows = all_holiday_tables_2[year].find_all('tr')
    count_is_zero = True
    for row in holiday_rows:
        if count_is_zero:
            count_is_zero = False
            continue
        else:
            all_holiday_rows_2[year].append(row)
    print('For year {} the number of holidays are  {}'.format(year, len(all_holiday_rows_2[year])))
# Out:
# For year 2014 the number of holidays are  28
# For year 2015 the number of holidays are  27
# For year 2016 the number of holidays are  29
# For year 2017 the number of holidays are  29
# For year 2018 the number of holidays are  28
# For year 2019 the number of holidays are  22

# %%
all_holidays_and_occasions_2 = {}
for year in years:
    all_holidays_and_occasions_2[year] = []
    for i in range(len(all_holiday_rows_2[year])):
        this_holidays_data = all_holiday_rows_2[year][i].find_all('td')
        date = this_holidays_data[2].text
        day = this_holidays_data[1].text
        occasion = this_holidays_data[0].text.strip()
        all_holidays_and_occasions_2[year].append([date, day, occasion])
all_holidays_and_occasions_2['2014'][:4]
# Out:
# [['December 23', 'Tuesday', 'Martyrdom of Imam Reza'],
#  ['January 19', 'Sunday', 'Birthday of Prophet Muhammad and Imam Sadeq'],
#  ['February 11', 'Tuesday', 'Revolution Day'],
#  ['March 20', 'Thursday', 'March Equinox']]

# %%
finalized_holidays_2 =[]
finalized_holidays_2.append('Date,Day,Occasion\n')
month_mappings_2 = {'January': '01', 'February': '02', 'March': '03', 'April': '04', 'May': '05', 'June': '06', 'July': '07', 'August': '08', 'September': '09', 'October':'10', 'November': '11', 'December': '12'}
for year in years:
    for row in all_holidays_and_occasions_2[year]:
        date = row[0].split()
        h_date = str(year)+'-'+month_mappings_2[date[0]]+'-'+date[1]
        row[2] = row[2].replace(',',' ')
        row[2] = row[2].replace('\n',' ')
        finalized_row = h_date+','+row[1]+','+row[2]+'\n'
        finalized_holidays_2.append(finalized_row)
finalized_holidays_2[:5]
# Out:
# ['Date,Day,Occasion\n',
#  '2014-12-23,Tuesday,Martyrdom of Imam Reza\n',
#  '2014-01-19,Sunday,Birthday of Prophet Muhammad and Imam Sadeq\n',
#  '2014-02-11,Tuesday,Revolution Day\n',
#  '2014-03-20,Thursday,March Equinox\n']

# %%
with open('holidays_'+str(STAR_YEAR)+'_'+str(END_YEAR)+'_v2.csv', 'w+') as fp:
    for row in finalized_holidays_2:
        fp.write(row)

# %%
file_content = pd.read_csv('holidays_'+str(STAR_YEAR)+'_'+str(END_YEAR)+'_v2.csv')
file_content
# Out:
#            Date        Day                                           Occasion
# 0    2014-12-23    Tuesday                             Martyrdom of Imam Reza
# 1    2014-01-19     Sunday        Birthday of Prophet Muhammad and Imam Sadeq
# 2    2014-02-11    Tuesday                                     Revolution Day
# 3    2014-03-20   Thursday                                      March Equinox
# 4    2014-03-20   Thursday                            Oil Nationalization Day
# 5    2014-03-21     Friday                          Norooz (Persian New Year)
# 6    2014-03-24     Monday                                     Norooz Holiday
# 7     2014-04-1    Tuesday                               Islamic Republic Day
# 8     2014-04-2  Wednesday                                         Nature Day
# 9     2014-04-3   Thursday                                Martyrdom of Fatima
# 10   2014-05-13    Tuesday                               Birthday of Imam Ali
# 11   2014-05-27    Tuesday                                Prophet's Ascension
# 12    2014-06-4  Wednesday                    Anniversary of Khomeini's Death
# 13    2014-06-5   Thursday                               Revolt of Khordad 15
# 14   2014-06-13     Friday                              Imam Mahdi's birthday
# 15   2014-06-21   Saturday                                      June Solstice
# 16   2014-07-19   Saturday                              Martyrdom of Imam Ali
# 17   2014-07-29    Tuesday  Eid-e-Fetr (End of Ramadan) Eid-al-Fitr is a h...
# 18   2014-07-30  Wednesday                    Eid-e-Fetr (Additional Holiday)
# 19   2014-08-22     Friday                            Martyrdom of Imam Sadeq
# 20   2014-09-23    Tuesday                                  September Equinox
# 21    2014-10-5     Sunday  Eid-e-Ghorban (Feast of Sacrifice) Eid al-Adha...
# 22   2014-10-13     Monday                                       Eid-e-Ghadir
# 23    2014-11-3     Monday                                            Tassoua
# 24    2014-11-4    Tuesday                                             Ashura
# 25   2014-12-13   Saturday                                            Arbaeen
# 26   2014-12-21     Sunday                                  December Solstice
# 27   2014-12-21     Sunday  Demise of Prophet Muhammad and Martyrdom of Im...
# 28   2015-12-29    Tuesday        Birthday of Prophet Muhammad and Imam Sadeq
# 29   2015-02-11  Wednesday                                     Revolution Day
# ..          ...        ...                                                ...
# 133  2018-09-20   Thursday                                             Ashura
# 134  2018-09-23     Sunday                                  September Equinox
# 135  2018-10-30    Tuesday                                            Arbaeen
# 136   2018-11-7  Wednesday  Demise of Prophet Muhammad and Martyrdom of Im...
# 137   2018-11-8   Thursday                             Martyrdom of Imam Reza
# 138  2018-11-16     Friday                  Martyrdom of Imam Hasan al-Askari
# 139  2018-11-25     Sunday        Birthday of Prophet Muhammad and Imam Sadeq
# 140  2018-12-21     Friday                                  December Solstice
# 141   2019-02-9   Saturday                                Martyrdom of Fatima
# 142  2019-02-11     Monday                                     Revolution Day
# 143  2019-03-20  Wednesday                                      March Equinox
# 144  2019-03-20  Wednesday                               Birthday of Imam Ali
# 145   2019-04-3  Wednesday                                Prophet's Ascension
# 146  2019-04-21     Sunday                              Imam Mahdi's birthday
# 147  2019-05-26     Sunday                              Martyrdom of Imam Ali
# 148   2019-06-5  Wednesday  Eid-e-Fetr (End of Ramadan) Eid-al-Fitr is a h...
# 149   2019-06-6   Thursday                    Eid-e-Fetr (Additional Holiday)
# 150  2019-06-21     Friday                                      June Solstice
# 151  2019-06-29   Saturday                            Martyrdom of Imam Sadeq
# 152  2019-08-12     Monday  Eid-e-Ghorban (Feast of Sacrifice) Eid al-Adha...
# 153  2019-08-20    Tuesday                                       Eid-e-Ghadir
# 154   2019-09-9     Monday                                            Tassoua
# 155  2019-09-10    Tuesday                                             Ashura
# 156  2019-09-23     Monday                                  September Equinox
# 157  2019-10-20     Sunday                                            Arbaeen
# 158  2019-10-28     Monday  Demise of Prophet Muhammad and Martyrdom of Im...
# 159  2019-10-29    Tuesday                             Martyrdom of Imam Reza
# 160   2019-11-6  Wednesday                  Martyrdom of Imam Hasan al-Askari
# 161  2019-11-15     Friday        Birthday of Prophet Muhammad and Imam Sadeq
# 162  2019-12-22     Sunday                                  December Solstice
#
# [163 rows x 3 columns]
